# %%
This notebook will be used for my capstone project
# Out:
#   File "<ipython-input-5-1d6fca95b259>", line 1
#     This notebook will be used for my capstone project
#                 ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

# %%
print('Hello capstone project course!')
# Out:
# Hello capstone project course!
